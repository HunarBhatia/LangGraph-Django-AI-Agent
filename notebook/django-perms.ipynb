# %%
import setup #notebooks/setup.py

setup.init()

# %%
from django.contrib.auth import get_user_model

User=get_user_model()

User.objects.all()
# Out:
# <QuerySet [<User: admin>]>

# %%
# Bhai finally django aur jupyter connect hogye!!! Itna mood kharab hua tha jis din nahi hua tha...

# %%
# We'll test out creating users with manual python perspective kyunki why not...

# %%
user_obj = User(
    username= "Staff"
)

user_obj
# Out:
# <User: Staff>

# %%
user_obj.save()

# %%
from documents.models import Document

doc_obj = Document(
    owner = user_obj,
    title = "Hello WORLD"
)
doc_obj
# Out:
# <Document: Document object (None)>

# %%
doc_obj.save()

# %%
doc_obj
# Out:
# <Document: Document object (2)>

# %%
user_obj = User.objects.last()
user_obj
# Out:
# <User: Staff>
