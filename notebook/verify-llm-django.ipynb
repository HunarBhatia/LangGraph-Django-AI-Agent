# %%
import setup
setup.init()

# %%
from ai.llms import get_openai_model

# %%
model = get_openai_model()

# %%
model.invoke("What is the best number in maths?")
# Out:
# AIMessage(content='The concept of the "best" number in mathematics is subjective and can vary depending on context and personal preference. However, several numbers are often highlighted for their unique properties and significance:\n\n1. **Zero (0)**: Represents the concept of nothingness and is the additive identity in mathematics.\n\n2. **One (1)**: The multiplicative identity, meaning any number multiplied by one remains unchanged.\n\n3. **Pi (π)**: Approximately 3.14159, it is the ratio of a circle\'s circumference to its diameter and is fundamental in geometry and trigonometry.\n\n4. **Euler\'s Number (e)**: Approximately 2.71828, it is the base of natural logarithms and is important in calculus, particularly in growth and decay problems.\n\n5. **The Golden Ratio (φ)**: Approximately 1.61803, it appears in various natural phenomena, art, and architecture.\n\n6. **Imaginary Unit (i)**: Defined as the square root of -1, it is essential in complex number theory.\n\n7. **Prime Numb
# ...
