# %%
import setup
setup.init()

# %%
from ai.tools import list_documents,get_document

# %%
config={
    "user_id":1
}

# %%
list_documents.invoke(None)
# Out:
# [{'id': <function id(obj, /)>, 'title': 'Test'},
#  {'id': <function id(obj, /)>, 'title': 'Hello WORLD'}]

# %%
get_document.invoke({"document_id":1})
# Out:
# {'id': 1, 'title': 'Test'}
