# %%
import setup
setup.init()

# %%
from langgraph.checkpoint.memory import InMemorySaver

# %%
from ai.agents import get_document_agent

# %%
import uuid
config={"configurable":{"user_id":"1","thread_id":uuid.uuid4()}}
checkpointer=InMemorySaver()
agent=get_document_agent(checkpointer=checkpointer)

# %%
response=agent.invoke(
    {
        "messages":
        [
            {"role":"user" , "content":"name all the documents that i have"}
        ]
    },
    config
)
response['messages'][-1].content
# Out:
# {'tags': [], 'metadata': {'user_id': '1', 'langgraph_step': 2, 'langgraph_node': 'tools', 'langgraph_triggers': ('__pregel_push',), 'langgraph_path': ('__pregel_push', 0, False), 'langgraph_checkpoint_ns': 'tools:3ba23c57-178b-479c-c470-8ff22f3eaebd', 'checkpoint_ns': 'tools:3ba23c57-178b-479c-c470-8ff22f3eaebd'}, 'callbacks': <langchain_core.callbacks.manager.CallbackManager object at 0x0000014B4347F5F0>, 'recursion_limit': 10000, 'configurable': {'user_id': '1', 'thread_id': UUID('23a95f31-1345-4c36-a55d-5f3074d748d6'), '__pregel_runtime': Runtime(context=None, store=None, stream_writer=<function Pregel.stream.<locals>.stream_writer at 0x0000014B435122A0>, previous=None), '__pregel_task_id': '3ba23c57-178b-479c-c470-8ff22f3eaebd', '__pregel_send': <built-in method extend of collections.deque object at 0x0000014B435C0400>, '__pregel_read': functools.partial(<function local_read at 0x0000014B414CE5C0>, PregelScratchpad(step=2, stop=10000, call_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x0000014B41244CA0>, interrupt_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x0000014B41244DC0>, get_null_resume=<function _scratchpad.<locals>.get_null_resume at 0x0000014B42F70680>, resume=[], subgraph_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x0000014B41244BE0>), {'messages': <langgraph.channels.binop.BinaryOperatorAggregate object at 0x0000014B43567680>, 'jump_to': <langgraph.channels.ephemeral_value.EphemeralValue object at 0x0000014B43567740>, 'structured_response': <langgraph.channels.last_value.LastValue object at 0x0000014B43567780>, '__start__': <langgraph.channels.ephemeral_value.EphemeralValue object at 0x0000014B43567800>, '__pregel_tasks': <langgraph.channels.topic.Topic object at 0x0000014B43567880>, 'branch:to:model': <langgraph.channels.ephemeral_value.EphemeralValue object at 0x0000014B43567A00>, 'branch:to:tools': <langgraph.channels.ephemeral_value.EphemeralValue object at 0x0000014B43567A40>}, {}, PregelTaskWrites(path=('__pregel_push', 0, False), name='tools', writes=deque([]), triggers=('__pregel_push',))), '__pregel_checkpointer': <langgraph.checkpoint.memory.InMemorySaver object at 0x0000014B42A1AE70>, 'checkpoint_map': {'': '1f0e6ca3-8184-68bc-8001-1e8eba84fe10'}, 'checkpoint_id': None, 'checkpoint_ns': 'tools:3ba23c57-178b-479c-c470-8ff22f3eaebd', '__pregel_scratchpad': PregelScratchpad(step=2, stop=10000, call_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x0000014B41244CA0>, interrupt_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x0000014B41244DC0>, get_null_resume=<function _scratchpad.<locals>.get_null_resume at 0x0000014B42F70680>, resume=[], subgraph_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x0000014B41244BE0>), '__pregel_call': functools.partial(<function _call at 0x0000014B41510540>, <weakref at 0x0000014B435AB290; to 'PregelExecutableTask' at 0x0000014B435436E0>, retry_policy=None, futures=<weakref at 0x0000014B435AB2E0; to 'FuturesDict' at 0x0000014B435AB250>, schedule_task=<bound method SyncPregelLoop.accept_push of <langgraph.pregel._loop.SyncPregelLoop object at 0x0000014B435804A0>>, submit=<weakref at 0x0000014B43577CD0; to 'BackgroundExecutor' at 0x0000014B432B7500>)}}
# 'Here are the documents you have:\n\n1. "Hello WORLD"\n2. "Leonardo DiCaprio"\n3. "Leonardo DiCaprio" (Note: There are two documents with the same title)'

# %%
response=agent.invoke(
    {
        "messages":
        [
            {"role":"user" , "content":"delete a document"}
        ]
    },
    config
)
response['messages'][-1].content
# Out:
# 'Please provide the ID of the document you would like to delete. Here are the available documents with their IDs:\n\n1. "Hello WORLD" (ID: 2)\n2. "Leonardo DiCaprio" (ID: 3)\n3. "Leonardo DiCaprio" (ID: 7)'

# %%
response=agent.invoke(
    {
        "messages":
        [
            {"role":"user" , "content":"delete the document with id 2"}
        ]
    },
    config
)
response['messages'][-1].content
# Out:
# 'The document with ID 2 ("Hello WORLD") has been successfully deleted.'

# %%
response=agent.invoke(
    {
        "messages":
        [
            {"role":"user" , "content":"update the document with id 7 and make its title bye-bye"}
        ]
    },
    config
)
response['messages'][-1].content
# Out:
# 'The document with ID 7 has been successfully updated with the new title "bye-bye".'

# %%
response = agent.invoke(
    {"messages":
    [
        {"role":"user","content":"delete all teh documents."}]},config
)
response['messages'][-1].content
# Out:
# 'All documents have been successfully deleted.'

# %%
response = agent.invoke(
    {
        "messages":[{
            "role":"user","content":"talk in hindi from now onwards until i ask you to turn it back"
        }]
    },config
)
response['messages'][-1].content
# Out:
# 'ठीक है, अब से मैं हिंदी में बात करूंगा। अगर आपको कुछ और जानना है या किसी चीज़ में मदद चाहिए, तो बेझिझक पूछें।'

# %%
response = agent.invoke(
    {
        "messages":[{
            "role":"user","content":"who is kishore kumar"
        }]
    },config
)
response['messages'][-1].content
# Out:
# 'किशोर कुमार एक प्रसिद्ध भारतीय गायक, अभिनेता, संगीतकार और फिल्म निर्माता थे। उनका जन्म 4 अगस्त 1929 को खंडवा, मध्य प्रदेश में हुआ था। वे हिंदी सिनेमा के सबसे बहुमुखी और लोकप्रिय गायकों में से एक माने जाते हैं। \n\nकिशोर कुमार ने अपने करियर की शुरुआत एक अभिनेता के रूप में की, लेकिन बाद में वे एक गायक के रूप में अधिक प्रसिद्ध हुए। उन्होंने कई हिट गाने गाए, जो आज भी बहुत लोकप्रिय हैं। उनके गाए हुए गाने जैसे "मेरे सपनों की रानी", "रूप तेरा मस्ताना", "पल पल दिल के पास", और "कुछ तो लोग कहेंगे" आज भी लोगों के दिलों में बसे हुए हैं।\n\nकिशोर कुमार ने अपने जीवन में कई पुरस्कार जीते और उन्हें चार बार सर्वश्रेष्ठ पार्श्व गायक के लिए फिल्मफेयर पुरस्कार से सम्मानित किया गया। उनका निधन 13 अक्टूबर 1987 को हुआ, लेकिन उनकी संगीत विरासत आज भी जीवित है।'

# %%
response = agent.invoke(
    {
        "messages":[{
            "role":"user","content":"switch back to english now "
        }]
    },config
)
response['messages'][-1].content
# Out:
# 'Sure! If you have any more questions or need assistance, feel free to ask in English.'
