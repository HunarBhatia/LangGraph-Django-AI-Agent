# %%
import setup
setup.init()

# %%
from ai.agents import get_document_agent

# %%
from langgraph.checkpoint.memory import InMemorySaver
checkpointer = InMemorySaver()

# %%
agent=get_document_agent(checkpointer)

# %%
import uuid
# Configure with thread_id for conversation memory
config = {"configurable": {"thread_id": str(uuid.uuid4())}}

# Invoke the agent
response = agent.invoke(
    {"messages": [{"role": "user", "content": "what are my recent documents? How many do I have in total?"}]},
    config
)

# Access the response
print(response["messages"][-1].content)
# Out:
# {'tags': [], 'metadata': {'thread_id': '744e8fbd-0e8b-43dc-9f56-5d0fcccd98c3', 'langgraph_step': 2, 'langgraph_node': 'tools', 'langgraph_triggers': ('__pregel_push',), 'langgraph_path': ('__pregel_push', 0, False), 'langgraph_checkpoint_ns': 'tools:814bac5d-0a61-c720-1428-6aeb691d50df', 'checkpoint_ns': 'tools:814bac5d-0a61-c720-1428-6aeb691d50df'}, 'callbacks': <langchain_core.callbacks.manager.CallbackManager object at 0x000001BA23B1F1A0>, 'recursion_limit': 10000, 'configurable': {'thread_id': '744e8fbd-0e8b-43dc-9f56-5d0fcccd98c3', '__pregel_runtime': Runtime(context=None, store=None, stream_writer=<function Pregel.stream.<locals>.stream_writer at 0x000001BA200BC0E0>, previous=None), '__pregel_task_id': '814bac5d-0a61-c720-1428-6aeb691d50df', '__pregel_send': <built-in method extend of collections.deque object at 0x000001BA23CC4220>, '__pregel_read': functools.partial(<function local_read at 0x000001BA22B991C0>, PregelScratchpad(step=2, stop=10000, call_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x000001BA23C7F820>, interrupt_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x000001BA23C7C3A0>, get_null_resume=<function _scratchpad.<locals>.get_null_resume at 0x000001BA23C16340>, resume=[], subgraph_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x000001BA23C7C4C0>), {'messages': <langgraph.channels.binop.BinaryOperatorAggregate object at 0x000001BA23C6DCC0>, 'jump_to': <langgraph.channels.ephemeral_value.EphemeralValue object at 0x000001BA23C6D740>, 'structured_response': <langgraph.channels.last_value.LastValue object at 0x000001BA23C6E940>, '__start__': <langgraph.channels.ephemeral_value.EphemeralValue object at 0x000001BA23C6E140>, '__pregel_tasks': <langgraph.channels.topic.Topic object at 0x000001BA23C6DF40>, 'branch:to:model': <langgraph.channels.ephemeral_value.EphemeralValue object at 0x000001BA23C6D540>, 'branch:to:tools': <langgraph.channels.ephemeral_value.EphemeralValue object at 0x000001BA23C6E1C0>}, {}, PregelTaskWrites(path=('__pregel_push', 0, False), name='tools', writes=deque([]), triggers=('__pregel_push',))), '__pregel_checkpointer': <langgraph.checkpoint.memory.InMemorySaver object at 0x000001BA235F5340>, 'checkpoint_map': {'': '1f0e6134-8bb8-682a-8001-c6c775fc3260'}, 'checkpoint_id': None, 'checkpoint_ns': 'tools:814bac5d-0a61-c720-1428-6aeb691d50df', '__pregel_scratchpad': PregelScratchpad(step=2, stop=10000, call_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x000001BA23C7F820>, interrupt_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x000001BA23C7C3A0>, get_null_resume=<function _scratchpad.<locals>.get_null_resume at 0x000001BA23C16340>, resume=[], subgraph_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x000001BA23C7C4C0>), '__pregel_call': functools.partial(<function _call at 0x000001BA22BCB060>, <weakref at 0x000001BA23CD1710; to 'PregelExecutableTask' at 0x000001BA23CE84D0>, retry_policy=None, futures=<weakref at 0x000001BA23CD2390; to 'FuturesDict' at 0x000001BA23CD1590>, schedule_task=<bound method SyncPregelLoop.accept_push of <langgraph.pregel._loop.SyncPregelLoop object at 0x000001BA23BB50D0>>, submit=<weakref at 0x000001BA23CC11D0; to 'BackgroundExecutor' at 0x000001BA231291F0>)}}
# You have a total of 2 recent documents. Here they are:
#
# 1. **Test**
# 2. **Hello WORLD**
